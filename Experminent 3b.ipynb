# %% [markdown]
# import   tensorflow   as   tf import   tensorflow_datasets   as   tfds from   tensorflow.keras.models   import   Sequential from   tensorflow.keras.layers   import   Dense, Dropout, Flatten from   tensorflow.keras.utils   import   to_categorical import   matplotlib.pyplot   as   plt import   numpy   as   np print ( "Loading EMINST Letters dataset..." ) (ds_train, ds_test), ds_info   =   tfds.load( 'emnist/letters' , split = [ 'train' ,   'test' ], shuffle_files = True , as_supervised = True , with_info = True , ) def   preprocess_emnist(image, label): image   =   tf.cast(image, tf.float32)   /   255.0 image   =   tf.image.transpose(image) return   image, label   -   1   # Adjust label to be 0-indexed train_data   =   ds_train. map (preprocess_emnist).batch( 32 ).prefetch(tf.data.AUTOTUNE) test_data   =   ds_test. map (preprocess_emnist).batch( 32 ).prefetch(tf.data.AUTOTUNE) with   tf.device( '/GPU:0' ): model   =   Sequential([ Flatten(input_shape = ( 28 ,   28 ,   1 )), Dense( 256 , activation = 'relu' ), Dropout( 0.2 ),   # Fixed dropout value Dense( 128 , activation = 'relu' ), Dense( 26 , activation = 'softmax' )   # Fixed activation and parenthesis ]) model. compile (optimizer = 'adam' , loss = 'sparse_categorical_crossentropy' , metrics history   =   model.fit(train_data, epochs = 10 , validation_data = test_data) def   get_letter(label): return   chr ( ord ( 'A' )   +   label) images, labels   =   next ( iter (test_data)) predictions   =   model.predict(images) plt.figure(figsize = ( 15 ,   4 )) for   i   in   range ( 10 ): plt.subplot( 1 ,   10 , i   +   1 ) plt.imshow(images[i].numpy().squeeze(), cmap = 'gray' ) pred_idx   =   np.argmax(predictions[i])   # Get predicted index true_idx   =   labels[i].numpy()   # Get true index

# %% [markdown]
# --- End of Page 1 ---

# %% [markdown]
# color   =   'green'   if   pred_idx   ==   true_idx   else   'red' plt.title( f"P:   { get_letter(pred_idx) } \n T:   { get_letter(true_idx) } " , color = color) plt.axis( 'off' ) plt.tight_layout() plt.show() loss, accuracy   =   model.evaluate(test_data, verbose = 0 ) print ( f" \n Final test accuracy:   { accuracy * 100 :.2f} %" ) Loading EMINST Letters dataset... WARNING:absl:Variant folder /root/tensorflow_datasets/emnist/letters/3.1.0 has no dataset_info.json Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/emnist/letters/3.1.0... Dl Completed...: 0 url [00:00, ? url/s] Dl Size...: 0 MiB [00:00, ? MiB/s] Extraction completed...: 0 file [00:00, ? file/s] Extraction completed...: 0 file [00:00, ? file/s] Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s] Generating train examples...: 0 examples [00:00, ? examples/s] Shuffling /root/tensorflow_datasets/emnist/letters/incomplete.SRAO65_3.1.0/emnist-train.tfrecord*...:   0%|   ... Generating test examples...: 0 examples [00:00, ? examples/s]

# %% [markdown]
# --- End of Page 2 ---

# %% [markdown]
# Shuffling /root/tensorflow_datasets/emnist/letters/incomplete.SRAO65_3.1.0/emnist-test.tfrecord*...:   0%|    ... Dataset emnist downloaded and prepared to /root/tensorflow_datasets/emnist/letters/3.1.0. Subsequent calls will reuse this data. Epoch 1/10 /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead. super().__init__(**kwargs)  ⯑ [1m2775/2775 ⯑ [0m  ⯑ [32m━━━━━━━━━━━━━━━━━━━━ ⯑ [0m ⯑ [37m ⯑ [0m  ⯑ [1m28s ⯑ [0m 10ms/step - accuracy: 0.6741 - loss: 1.1003 - val_accuracy: 0.8462 - val_loss: 0.4708 Epoch 2/10  ⯑ [1m2775/2775 ⯑ [0m  ⯑ [32m━━━━━━━━━━━━━━━━━━━━ ⯑ [0m ⯑ [37m ⯑ [0m  ⯑ [1m20s ⯑ [0m 7ms/step - accuracy: 0.8508 - loss: 0.4706 - val_accuracy: 0.8657 - val_loss: 0.4024 Epoch 3/10  ⯑ [1m2775/2775 ⯑ [0m  ⯑ [32m━━━━━━━━━━━━━━━━━━━━ ⯑ [0m ⯑ [37m ⯑ [0m  ⯑ [1m19s ⯑ [0m 7ms/step - accuracy: 0.8732 - loss: 0.3889 - val_accuracy: 0.8718 - val_loss: 0.3847 Epoch 4/10  ⯑ [1m2775/2775 ⯑ [0m  ⯑ [32m━━━━━━━━━━━━━━━━━━━━ ⯑ [0m ⯑ [37m ⯑ [0m  ⯑ [1m22s ⯑ [0m 7ms/step - accuracy: 0.8846 - loss: 0.3487 - val_accuracy: 0.8814 - val_loss: 0.3626 Epoch 5/10  ⯑ [1m2775/2775 ⯑ [0m  ⯑ [32m━━━━━━━━━━━━━━━━━━━━ ⯑ [0m ⯑ [37m ⯑ [0m  ⯑ [1m18s ⯑ [0m 6ms/step - accuracy: 0.8934 - loss: 0.3179 - val_accuracy: 0.8839 - val_loss: 0.3629 Epoch 6/10  ⯑ [1m2775/2775 ⯑ [0m  ⯑ [32m━━━━━━━━━━━━━━━━━━━━ ⯑ [0m ⯑ [37m ⯑ [0m  ⯑ [1m19s ⯑ [0m 7ms/step - accuracy: 0.8978 - loss: 0.3007 - val_accuracy: 0.8814 - val_loss: 0.3587 Epoch 7/10  ⯑ [1m2775/2775 ⯑ [0m  ⯑ [32m━━━━━━━━━━━━━━━━━━━━ ⯑ [0m ⯑ [37m ⯑ [0m  ⯑ [1m19s ⯑ [0m 7ms/step - accuracy: 0.9039 - loss: 0.2768 - val_accuracy: 0.8844 - val_loss: 0.3588 Epoch 8/10  ⯑ [1m2775/2775 ⯑ [0m  ⯑ [32m━━━━━━━━━━━━━━━━━━━━ ⯑ [0m ⯑ [37m ⯑ [0m  ⯑ [1m22s ⯑ [0m 8ms/step - accuracy: 0.9080 - loss: 0.2641 - val_accuracy: 0.8876 - val_loss: 0.3541 Epoch 9/10  ⯑ [1m2775/2775 ⯑ [0m  ⯑ [32m━━━━━━━━━━━━━━━━━━━━ ⯑ [0m ⯑ [37m ⯑ [0m  ⯑ [1m21s ⯑ [0m 8ms/step - accuracy: 0.9118 - loss: 0.2518 - val_accuracy: 0.8884 - val_loss: 0.3592 Epoch 10/10  ⯑ [1m2775/2775 ⯑ [0m  ⯑ [32m━━━━━━━━━━━━━━━━━━━━ ⯑ [0m ⯑ [37m ⯑ [0m  ⯑ [1m40s ⯑ [0m 7ms/step - accuracy: 0.9124 - loss: 0.2471 - val_accuracy: 0.8946 - val_loss: 0.3512  ⯑ [1m1/1 ⯑ [0m  ⯑ [32m━━━━━━━━━━━━━━━━━━━━ ⯑ [0m ⯑ [37m ⯑ [0m  ⯑ [1m0s ⯑ [0m 77ms/step  png  Final test accuracy: 89.46%
